# %% [markdown]
# ## The `type()` Function
#
# The `type()` function returns the data type of a particular Python object.

# %%
x = 1
# the type() function
type(x)

# %% [markdown]
# ## Numbers & Bools

# %%
# Numbers and Bools
# Integer
42
# Float
3.14
# Scientific Notation
3.456e11
print(3.456*(10**11))
print(345600000000.0)
print(3.456e11)
