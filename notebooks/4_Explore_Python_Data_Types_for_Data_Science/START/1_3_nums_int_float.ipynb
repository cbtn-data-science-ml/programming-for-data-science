# %% [markdown]
# ## The `type()` Function
#
# The `type()` function returns the data type of a particular Python object.

# %% [markdown]
# ## The `type()` Function
#
# The `type()` function returns the data type of a particular Python object.

# %%
x = 1
# the type() function
type(x)
# Out:
# int

# %% [markdown]
# ## Numbers & Bools

# %%
# Numbers

# Integer
a = 42
# Float
b = 3.14
# Scientific Notation
c = 3.456e11

# %%
type(c)
# Out:
# float

# %%
d = int(c)
d
# Out:
# 345600000000
