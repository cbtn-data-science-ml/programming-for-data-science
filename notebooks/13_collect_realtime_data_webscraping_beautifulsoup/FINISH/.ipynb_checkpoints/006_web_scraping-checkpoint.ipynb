# %% [markdown]
# # Searching and extracting: `find_all()` PART III

# %%
# import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Get HTML into Python

# %%
# assign HTML url to varible: url
# url ="https://webscraper.io/test-sites/e-commerce/allinone/phones"
url ="https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets"

# get the HTML from url and assign to variable: page
page = requests.get(url)
page # The HTTP 200 OK success status response code = request has succeeded.
# Out:
# <Response [200]>

# %%
# grab the HTML as text(string)
# parses it into Python and assign to variable: soup
soup = BeautifulSoup(page.text,"lxml")
soup # retruns the HTML
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Anti-flicker snippet (recommended)  -->
# <style>.async-hide {
# 		opacity: 0 !important
# 	} </style>
# <script>(function (a, s, y, n, c, h, i, d, e) {
# 		s.className += ' ' + y;
# 		h.start = 1 * new Date;
# 		h.end = i = function () {
# 			s.className = s.className.replace(RegExp(' ?' + y), '')
# 		};
# 		(a[n] = a[n] || []).hide = h;
# 		setTimeout(function () {
# 			i();
# 			h.end = null
# 		}, c);
# 		h.timeout = c;
# 	})(window, document.documentElement, 'async-hide', 'dataLayer', 4000,
# 		{'GTM-NVFPDWB': true});</script>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# ...

# %% [markdown]
# ## Create a table with multiple column representing various tag values

# %%
# get product names
product_name = soup.find_all('a', class_ = 'title')
product_name
# Out:
# [<a class="title" href="/test-sites/e-commerce/allinone/product/495" title="Lenovo IdeaTab">Lenovo IdeaTab</a>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/500" title="IdeaTab A3500L">IdeaTab A3500L</a>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/496" title="Acer Iconia">Acer Iconia</a>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/503" title="Galaxy Tab 3">Galaxy Tab 3</a>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/512" title="Iconia B1-730HD">Iconia B1-730HD</a>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/508" title="Memo Pad HD 7">Memo Pad HD 7</a>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/497" title="Asus MeMO Pad">Asus MeMO Pad</a>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/498" title="Amazon Kindle">Amazon Kindle</a>,
# ...

# %%
# get product prices
product_price = soup.find_all('h4', class_ = 'pull-right price')
product_price
# Out:
# [<h4 class="pull-right price">$69.99</h4>,
#  <h4 class="pull-right price">$88.99</h4>,
#  <h4 class="pull-right price">$96.99</h4>,
#  <h4 class="pull-right price">$97.99</h4>,
#  <h4 class="pull-right price">$99.99</h4>,
#  <h4 class="pull-right price">$101.99</h4>,
#  <h4 class="pull-right price">$102.99</h4>,
#  <h4 class="pull-right price">$103.99</h4>,
#  <h4 class="pull-right price">$107.99</h4>,
#  <h4 class="pull-right price">$121.99</h4>,
#  <h4 class="pull-right price">$130.99</h4>,
#  <h4 class="pull-right price">$148.99</h4>,
#  <h4 class="pull-right price">$172.99</h4>,
#  <h4 class="pull-right price">$233.99</h4>,
#  <h4 class="pull-right price">$251.99</h4>,
#  <h4 class="pull-right price">$320.99</h4>,
#  <h4 class="pull-right price">$399.99</h4>,
#  <h4 class="pull-right price">$489.99</h4>,
#  <h4 class="pull-right price">$537.99</h4>,
#  <h4 class="pull-right price">$587.99</h4>,
#  <h4 class="pull-right price">$603.99</h4>]

# %%
import re
# get product reviews
product_review = soup.find_all('p', class_ = re.compile('pull'))
product_review
# Out:
# [<p class="pull-right">7 reviews</p>,
#  <p class="pull-right">7 reviews</p>,
#  <p class="pull-right">7 reviews</p>,
#  <p class="pull-right">2 reviews</p>,
#  <p class="pull-right">1 reviews</p>,
#  <p class="pull-right">10 reviews</p>,
#  <p class="pull-right">14 reviews</p>,
#  <p class="pull-right">3 reviews</p>,
#  <p class="pull-right">14 reviews</p>,
#  <p class="pull-right">13 reviews</p>,
#  <p class="pull-right">11 reviews</p>,
#  <p class="pull-right">9 reviews</p>,
#  <p class="pull-right">8 reviews</p>,
#  <p class="pull-right">1 reviews</p>,
#  <p class="pull-right">14 reviews</p>,
#  <p class="pull-right">7 reviews</p>,
#  <p class="pull-right">12 reviews</p>,
#  <p class="pull-right">9 reviews</p>,
#  <p class="pull-right">8 reviews</p>,
#  <p class="pull-right">6 reviews</p>,
#  <p class="pull-right">7 reviews</p>]

# %%
# get product reviews
product_description = soup.find_all('p', class_ = re.compile('description'))
product_description
# Out:
# [<p class="description">7" screen, Android</p>,
#  <p class="description">Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2</p>,
#  <p class="description">7" screen, Android, 16GB</p>,
#  <p class="description">7", 8GB, Wi-Fi, Android 4.2, White</p>,
#  <p class="description">Black, 7", 1.6GHz Dual-Core, 8GB, Android 4.4</p>,
#  <p class="description">IPS, Dual-Core 1.2GHz, 8GB, Android 4.3</p>,
#  <p class="description">7" screen, Android, 8GB</p>,
#  <p class="description">6" screen, wifi</p>,
#  <p class="description">7", 8GB, Wi-Fi, Android 4.2, Yellow</p>,
#  <p class="description">Blue, 8" IPS, Quad-Core 1.3GHz, 16GB, Android 4.2</p>,
#  <p class="description">White, 7", Atom 1.2GHz, 8GB, Android 4.4</p>,
#  <p class="description">Blue, 7" IPS, Quad-Core 1.3GHz, 8GB, 3G, Android 4.2</p>,
#  <p class="description">Silver, 7" IPS, Quad-Core 1.2Ghz, 16GB, 3G, Android 4.2</p>,
#  <p class="description">LTE (SM-T235), Quad-Core 1.2GHz, 8GB, Black</p>,
# ...

# %% [markdown]
# ## Create a `for` loops to gather everything

# %%
product_name_list = []

for i in product_name:
  name = i.text
  product_name_list.append(name)


product_name_list
# Out:
# ['Lenovo IdeaTab',
#  'IdeaTab A3500L',
#  'Acer Iconia',
#  'Galaxy Tab 3',
#  'Iconia B1-730HD',
#  'Memo Pad HD 7',
#  'Asus MeMO Pad',
#  'Amazon Kindle',
#  'Galaxy Tab 3',
#  'IdeaTab A8-50',
#  'MeMO Pad 7',
#  'IdeaTab A3500-H',
#  'IdeaTab S5000',
#  'Galaxy Tab 4',
#  'Galaxy Tab',
#  'MeMo PAD FHD 10',
#  'Galaxy Note',
#  'Galaxy Note',
#  'iPad Mini Retina',
#  'Galaxy Note 10.1',
#  'Apple iPad Air']

# %%
product_price_list = []

for i in product_price:
  price = i.text
  product_price_list.append(price)

product_price_list
# Out:
# ['$69.99',
#  '$88.99',
#  '$96.99',
#  '$97.99',
#  '$99.99',
#  '$101.99',
#  '$102.99',
#  '$103.99',
#  '$107.99',
#  '$121.99',
#  '$130.99',
#  '$148.99',
#  '$172.99',
#  '$233.99',
#  '$251.99',
#  '$320.99',
#  '$399.99',
#  '$489.99',
#  '$537.99',
#  '$587.99',
#  '$603.99']

# %%
product_review_list = []

for i in product_review:
  review = i.text
  product_review_list.append(review)

product_review_list
# Out:
# ['7 reviews',
#  '7 reviews',
#  '7 reviews',
#  '2 reviews',
#  '1 reviews',
#  '10 reviews',
#  '14 reviews',
#  '3 reviews',
#  '14 reviews',
#  '13 reviews',
#  '11 reviews',
#  '9 reviews',
#  '8 reviews',
#  '1 reviews',
#  '14 reviews',
#  '7 reviews',
#  '12 reviews',
#  '9 reviews',
#  '8 reviews',
#  '6 reviews',
#  '7 reviews']

# %%
product_description_list = []

for i in product_description:
  description = i.text
  product_description_list.append(description)

product_description_list
# Out:
# ['7" screen, Android',
#  'Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2',
#  '7" screen, Android, 16GB',
#  '7", 8GB, Wi-Fi, Android 4.2, White',
#  'Black, 7", 1.6GHz Dual-Core, 8GB, Android 4.4',
#  'IPS, Dual-Core 1.2GHz, 8GB, Android 4.3',
#  '7" screen, Android, 8GB',
#  '6" screen, wifi',
#  '7", 8GB, Wi-Fi, Android 4.2, Yellow',
#  'Blue, 8" IPS, Quad-Core 1.3GHz, 16GB, Android 4.2',
#  'White, 7", Atom 1.2GHz, 8GB, Android 4.4',
#  'Blue, 7" IPS, Quad-Core 1.3GHz, 8GB, 3G, Android 4.2',
#  'Silver, 7" IPS, Quad-Core 1.2Ghz, 16GB, 3G, Android 4.2',
#  'LTE (SM-T235), Quad-Core 1.2GHz, 8GB, Black',
#  '16GB, White',
#  'White, 10.1" IPS, 1.6GHz, 2GB, 16GB, Android 4.2',
#  '10.1", 3G, Android 4.0, Garnet Red',
#  '12.2", 32GB, WiFi, Android 4.4, White',
#  'Wi-Fi + Cellular, 32GB, Silver',
#  '10.1", 32GB, Black',
#  'Wi-Fi, 64GB, Silver']

# %% [markdown]
# ## Convert to pandas DataFrame

# %%
import pandas as pd

# %%
table = pd.DataFrame({'Product Name':product_name_list, 'Product Price':product_price_list, 'Product Review':product_review_list, 'Product Description':product_description_list})

# %%
table
# Out:
#         Product Name Product Price Product Review  \
# 0     Lenovo IdeaTab        $69.99      7 reviews
# 1     IdeaTab A3500L        $88.99      7 reviews
# 2        Acer Iconia        $96.99      7 reviews
# 3       Galaxy Tab 3        $97.99      2 reviews
# 4    Iconia B1-730HD        $99.99      1 reviews
# 5      Memo Pad HD 7       $101.99     10 reviews
# 6      Asus MeMO Pad       $102.99     14 reviews
# 7      Amazon Kindle       $103.99      3 reviews
# 8       Galaxy Tab 3       $107.99     14 reviews
# 9      IdeaTab A8-50       $121.99     13 reviews
# 10        MeMO Pad 7       $130.99     11 reviews
# 11   IdeaTab A3500-H       $148.99      9 reviews
# 12     IdeaTab S5000       $172.99      8 reviews
# 13      Galaxy Tab 4       $233.99      1 reviews
# 14        Galaxy Tab       $251.99     14 reviews
# 15   MeMo PAD FHD 10       $320.99      7 reviews
# 16       Galaxy Note       $399.99     12 reviews
# 17       Galaxy Note       $489.99      9 reviews
# ...

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         21 non-null     object
#  1   Product Price        21 non-null     object
#  2   Product Review       21 non-null     object
#  3   Product Description  21 non-null     object
# dtypes: object(4)
# memory usage: 800.0+ bytes

# %%
# count: count of entries
# unique: unique values
# top: topmost common value
# freq: the frequency of the most common value
table.describe()
# Out:
#         Product Name Product Price Product Review Product Description
# count             21            21             21                  21
# unique            19            21             12                  21
# top     Galaxy Tab 3        $97.99      7 reviews  7" screen, Android
# freq               2             1              5                   1
